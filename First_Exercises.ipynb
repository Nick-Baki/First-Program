# %%
A=1200000
B=300000
C=A-B
D=6
E=C/D
print("Total_Price: ",A,"RWF")
print("Deposit_Amount: ",B,"RWF")
print("Remaining_Balance: ",C,"RWF")
print("Monthly_Installment_Amount: ",E,"RWF")
# Out:
# Total_Price:  1200000 RWF
# Deposit_Amount:  300000 RWF
# Remaining_Balance:  900000 RWF
# Monthly_Installment_Amount:  150000.0 RWF

# %%
A=240000
B=3
C=A/B
print("Room_Cost: ",A,"RWF")
print("Student_Number: ",B)
print("Each_Student_Payment: ",C,"RWF")
# Out:
# Room_Cost:  240000 RWF
# Student_Number:  3
# Each_Student_Payment:  80000.0 RWF

# %%
A=2.5
B=1800
C=5
D=A*C
E=D*B
print("Total_Fuel_Consumed: ",D,"Liters")
print("Total_Fuel_Cost: ",E,"RWF")
# Out:
# Total_Fuel_Consumed:  12.5 Liters
# Total_Fuel_Cost:  22500.0 RWF

# %%
A=85
B=50
C=A*B
print("Total_Printing_Cost: ",C,"RWF")
# Out:
# Total_Printing_Cost:  4250 RWF
